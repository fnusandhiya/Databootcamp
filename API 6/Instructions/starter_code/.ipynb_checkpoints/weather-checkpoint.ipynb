# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import csv
import time
import openweathermapy.core as owm

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)
        

city_data = pd.DataFrame({"City": cities, "Country": countries})
city_data.head()

city_data["Cloudiness"] = ""
city_data["Date"] = ""
city_data["Humidity"] = ""
city_data["Lat"] = ""
city_data["Lng"] = ""
city_data["Max Temp"] = ""
city_data["Wind Speed"] = ""

city_data.head()

# Print the city count to confirm sufficient count
len(city_data)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Openweather URL and API key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
api_key = "7877738b651f6172dfb2597fe3669dab"
row_count = 0

#loop through city row to perform API calls
print("*************************")
print("BEGINNING DATA RETRIEVAL")
print("*************************")
for index, row in city_data.iterrows():
    query_url = url + "appid=" + api_key + "&units=" + units + "&q=" + (row['City'])
    response = requests.get(query_url).json()
    print("-------------------------------")
    print(f"Processing City#: {row_count + 1} | {row['City']}")
    print(f"This is the requested URL: {query_url}")
    row_count += 1
    
    try:
        city_data.set_value(index, "Cloudiness", response["clouds"]["all"])
        city_data.set_value(index, "Date", response["dt"])
        city_data.set_value(index, "Humidity", response["main"]["humidity"])
        city_data.set_value(index, "Lat", response["coord"]["lat"])
        city_data.set_value(index, "Lng", response["coord"]["lon"])
        city_data.set_value(index, "Max Temp", response["main"]["temp_max"])
        city_data.set_value(index, "Wind Speed", response["wind"]["speed"])
    except:
        print("City not found. Skipping...")
     
    
    if row_count % 55 == 0:
        print("********************")
        print("PAUSE FOR 60 SECONDS")
        print("********************")
        time.sleep(60)
    
print("*************************")
print("DATA RETRIEVAL COMPLETE")
print("*************************")
# Out:
# *************************
# BEGINNING DATA RETRIEVAL
# *************************
# -------------------------------
# Processing City#: 1 | venado tuerto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=venado tuerto
# -------------------------------
# Processing City#: 2 | martapura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=martapura
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# -------------------------------
# Processing City#: 3 | jamestown
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=jamestown
# -------------------------------
# Processing City#: 4 | barrow
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=barrow
# -------------------------------
# Processing City#: 5 | rikitea
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=rikitea
# -------------------------------
# Processing City#: 6 | tura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tura
# -------------------------------
# Processing City#: 7 | butaritari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=butaritari
# -------------------------------
# Processing City#: 8 | bengkulu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bengkulu
# City not found. Skipping...
# -------------------------------
# Processing City#: 9 | albany
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=albany
# -------------------------------
# Processing City#: 10 | de-kastri
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=de-kastri
# -------------------------------
# Processing City#: 11 | hithadhoo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hithadhoo
# -------------------------------
# Processing City#: 12 | trinidad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=trinidad
# -------------------------------
# Processing City#: 13 | sol-iletsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sol-iletsk
# -------------------------------
# Processing City#: 14 | castro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=castro
# -------------------------------
# Processing City#: 15 | broken hill
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=broken hill
# -------------------------------
# Processing City#: 16 | illoqqortoormiut
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=illoqqortoormiut
# City not found. Skipping...
# -------------------------------
# Processing City#: 17 | narsaq
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=narsaq
# -------------------------------
# Processing City#: 18 | katsuura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=katsuura
# -------------------------------
# Processing City#: 19 | nikolskoye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nikolskoye
# -------------------------------
# Processing City#: 20 | kyaiklat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kyaiklat
# -------------------------------
# Processing City#: 21 | sangmelima
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sangmelima
# -------------------------------
# Processing City#: 22 | mataura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mataura
# -------------------------------
# Processing City#: 23 | tahoua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tahoua
# -------------------------------
# Processing City#: 24 | kaitangata
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kaitangata
# -------------------------------
# Processing City#: 25 | ushuaia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ushuaia
# -------------------------------
# Processing City#: 26 | mys shmidta
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mys shmidta
# City not found. Skipping...
# -------------------------------
# Processing City#: 27 | tuatapere
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tuatapere
# -------------------------------
# Processing City#: 28 | meulaboh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=meulaboh
# -------------------------------
# Processing City#: 29 | chichimila
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chichimila
# -------------------------------
# Processing City#: 30 | tazmalt
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tazmalt
# -------------------------------
# Processing City#: 31 | nanortalik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nanortalik
# -------------------------------
# Processing City#: 32 | margate
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=margate
# -------------------------------
# Processing City#: 33 | vizinga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vizinga
# -------------------------------
# Processing City#: 34 | hobart
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hobart
# -------------------------------
# Processing City#: 35 | morehead
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=morehead
# -------------------------------
# Processing City#: 36 | busselton
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=busselton
# -------------------------------
# Processing City#: 37 | puerto baquerizo moreno
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=puerto baquerizo moreno
# -------------------------------
# Processing City#: 38 | swift current
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=swift current
# -------------------------------
# Processing City#: 39 | umm lajj
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=umm lajj
# -------------------------------
# Processing City#: 40 | lorengau
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=lorengau
# -------------------------------
# Processing City#: 41 | opuwo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=opuwo
# -------------------------------
# Processing City#: 42 | hermanus
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hermanus
# -------------------------------
# Processing City#: 43 | longlac
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=longlac
# City not found. Skipping...
# -------------------------------
# Processing City#: 44 | vestmannaeyjar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vestmannaeyjar
# -------------------------------
# Processing City#: 45 | flinders
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=flinders
# -------------------------------
# Processing City#: 46 | souillac
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=souillac
# -------------------------------
# Processing City#: 47 | ribeira grande
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ribeira grande
# -------------------------------
# Processing City#: 48 | phalaborwa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=phalaborwa
# -------------------------------
# Processing City#: 49 | punta arenas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=punta arenas
# -------------------------------
# Processing City#: 50 | cherskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=cherskiy
# -------------------------------
# Processing City#: 51 | salinopolis
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=salinopolis
# -------------------------------
# Processing City#: 52 | chiang klang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chiang klang
# -------------------------------
# Processing City#: 53 | birao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=birao
# -------------------------------
# Processing City#: 54 | sarh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sarh
# -------------------------------
# Processing City#: 55 | tekirdag
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tekirdag
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 56 | thompson
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=thompson
# -------------------------------
# Processing City#: 57 | bathsheba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bathsheba
# -------------------------------
# Processing City#: 58 | sitka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sitka
# -------------------------------
# Processing City#: 59 | yellowknife
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=yellowknife
# -------------------------------
# Processing City#: 60 | malartic
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=malartic
# -------------------------------
# Processing City#: 61 | sorland
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sorland
# -------------------------------
# Processing City#: 62 | new norfolk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=new norfolk
# -------------------------------
# Processing City#: 63 | ponta do sol
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ponta do sol
# -------------------------------
# Processing City#: 64 | bluff
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bluff
# -------------------------------
# Processing City#: 65 | mar del plata
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mar del plata
# -------------------------------
# Processing City#: 66 | attawapiskat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=attawapiskat
# City not found. Skipping...
# -------------------------------
# Processing City#: 67 | saint-pierre
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=saint-pierre
# -------------------------------
# Processing City#: 68 | atuona
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=atuona
# -------------------------------
# Processing City#: 69 | komsomolskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=komsomolskiy
# -------------------------------
# Processing City#: 70 | esperance
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=esperance
# -------------------------------
# Processing City#: 71 | havoysund
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=havoysund
# -------------------------------
# Processing City#: 72 | husavik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=husavik
# -------------------------------
# Processing City#: 73 | epernay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=epernay
# -------------------------------
# Processing City#: 74 | slamannan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=slamannan
# -------------------------------
# Processing City#: 75 | dudinka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=dudinka
# -------------------------------
# Processing City#: 76 | victoria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=victoria
# -------------------------------
# Processing City#: 77 | suratgarh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=suratgarh
# -------------------------------
# Processing City#: 78 | praia da vitoria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=praia da vitoria
# -------------------------------
# Processing City#: 79 | bonthe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bonthe
# -------------------------------
# Processing City#: 80 | goderich
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=goderich
# -------------------------------
# Processing City#: 81 | fomboni
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=fomboni
# -------------------------------
# Processing City#: 82 | arraial do cabo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=arraial do cabo
# -------------------------------
# Processing City#: 83 | saint george
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=saint george
# -------------------------------
# Processing City#: 84 | mananjary
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mananjary
# -------------------------------
# Processing City#: 85 | kavaratti
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kavaratti
# -------------------------------
# Processing City#: 86 | port lincoln
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port lincoln
# -------------------------------
# Processing City#: 87 | torring
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=torring
# -------------------------------
# Processing City#: 88 | pevek
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pevek
# -------------------------------
# Processing City#: 89 | vaini
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vaini
# -------------------------------
# Processing City#: 90 | plettenberg bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=plettenberg bay
# -------------------------------
# Processing City#: 91 | pozo colorado
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pozo colorado
# -------------------------------
# Processing City#: 92 | longyearbyen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=longyearbyen
# -------------------------------
# Processing City#: 93 | acajutla
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=acajutla
# -------------------------------
# Processing City#: 94 | neiafu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=neiafu
# -------------------------------
# Processing City#: 95 | sorvag
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sorvag
# City not found. Skipping...
# -------------------------------
# Processing City#: 96 | biak
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=biak
# -------------------------------
# Processing City#: 97 | cape town
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=cape town
# -------------------------------
# Processing City#: 98 | ancud
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ancud
# -------------------------------
# Processing City#: 99 | qaanaaq
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=qaanaaq
# -------------------------------
# Processing City#: 100 | kapaa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kapaa
# -------------------------------
# Processing City#: 101 | bredasdorp
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bredasdorp
# -------------------------------
# Processing City#: 102 | chlum u trebone
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chlum u trebone
# -------------------------------
# Processing City#: 103 | aguimes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=aguimes
# -------------------------------
# Processing City#: 104 | port alfred
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port alfred
# -------------------------------
# Processing City#: 105 | vaitupu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vaitupu
# City not found. Skipping...
# -------------------------------
# Processing City#: 106 | westport
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=westport
# -------------------------------
# Processing City#: 107 | marawi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=marawi
# -------------------------------
# Processing City#: 108 | ellisras
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ellisras
# -------------------------------
# Processing City#: 109 | sao joao da barra
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sao joao da barra
# -------------------------------
# Processing City#: 110 | bahia blanca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bahia blanca
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 111 | temiscaming
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=temiscaming
# -------------------------------
# Processing City#: 112 | hambantota
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hambantota
# -------------------------------
# Processing City#: 113 | usinsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=usinsk
# -------------------------------
# Processing City#: 114 | carutapera
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=carutapera
# -------------------------------
# Processing City#: 115 | skalistyy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=skalistyy
# City not found. Skipping...
# -------------------------------
# Processing City#: 116 | georgetown
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=georgetown
# -------------------------------
# Processing City#: 117 | isfana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=isfana
# -------------------------------
# Processing City#: 118 | salalah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=salalah
# -------------------------------
# Processing City#: 119 | ormara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ormara
# -------------------------------
# Processing City#: 120 | avarua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=avarua
# -------------------------------
# Processing City#: 121 | chokurdakh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chokurdakh
# -------------------------------
# Processing City#: 122 | bud
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bud
# -------------------------------
# Processing City#: 123 | barbar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=barbar
# City not found. Skipping...
# -------------------------------
# Processing City#: 124 | progreso
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=progreso
# -------------------------------
# Processing City#: 125 | nam tha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nam tha
# City not found. Skipping...
# -------------------------------
# Processing City#: 126 | krasnousolskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=krasnousolskiy
# City not found. Skipping...
# -------------------------------
# Processing City#: 127 | santa isabel do rio negro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=santa isabel do rio negro
# -------------------------------
# Processing City#: 128 | bambous virieux
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bambous virieux
# -------------------------------
# Processing City#: 129 | yaan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=yaan
# -------------------------------
# Processing City#: 130 | taolanaro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=taolanaro
# City not found. Skipping...
# -------------------------------
# Processing City#: 131 | port ellen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port ellen
# City not found. Skipping...
# -------------------------------
# Processing City#: 132 | ayan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ayan
# -------------------------------
# Processing City#: 133 | bereda
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bereda
# -------------------------------
# Processing City#: 134 | road town
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=road town
# -------------------------------
# Processing City#: 135 | chuy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chuy
# -------------------------------
# Processing City#: 136 | indianola
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=indianola
# -------------------------------
# Processing City#: 137 | usevya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=usevya
# City not found. Skipping...
# -------------------------------
# Processing City#: 138 | springfield
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=springfield
# -------------------------------
# Processing City#: 139 | talnakh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=talnakh
# -------------------------------
# Processing City#: 140 | cabo san lucas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=cabo san lucas
# -------------------------------
# Processing City#: 141 | jiuquan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=jiuquan
# -------------------------------
# Processing City#: 142 | vao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vao
# -------------------------------
# Processing City#: 143 | torbay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=torbay
# -------------------------------
# Processing City#: 144 | lebu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=lebu
# -------------------------------
# Processing City#: 145 | aleksandrov gay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=aleksandrov gay
# -------------------------------
# Processing City#: 146 | iranshahr
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=iranshahr
# -------------------------------
# Processing City#: 147 | orocue
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=orocue
# -------------------------------
# Processing City#: 148 | raga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=raga
# City not found. Skipping...
# -------------------------------
# Processing City#: 149 | starkville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=starkville
# -------------------------------
# Processing City#: 150 | luderitz
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=luderitz
# -------------------------------
# Processing City#: 151 | vardo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vardo
# -------------------------------
# Processing City#: 152 | chupa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chupa
# -------------------------------
# Processing City#: 153 | thunder bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=thunder bay
# -------------------------------
# Processing City#: 154 | east london
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=east london
# -------------------------------
# Processing City#: 155 | yerbogachen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=yerbogachen
# -------------------------------
# Processing City#: 156 | laguna
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=laguna
# -------------------------------
# Processing City#: 157 | araouane
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=araouane
# -------------------------------
# Processing City#: 158 | yerofey pavlovich
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=yerofey pavlovich
# -------------------------------
# Processing City#: 159 | scarborough
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=scarborough
# -------------------------------
# Processing City#: 160 | bossangoa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bossangoa
# -------------------------------
# Processing City#: 161 | tiksi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tiksi
# -------------------------------
# Processing City#: 162 | abu samrah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=abu samrah
# -------------------------------
# Processing City#: 163 | kavieng
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kavieng
# -------------------------------
# Processing City#: 164 | shuiji
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=shuiji
# -------------------------------
# Processing City#: 165 | tessalit
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tessalit
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 166 | shellbrook
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=shellbrook
# -------------------------------
# Processing City#: 167 | la sarre
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=la sarre
# -------------------------------
# Processing City#: 168 | belushya guba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=belushya guba
# City not found. Skipping...
# -------------------------------
# Processing City#: 169 | dikson
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=dikson
# -------------------------------
# Processing City#: 170 | arona
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=arona
# -------------------------------
# Processing City#: 171 | hay river
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hay river
# -------------------------------
# Processing City#: 172 | nsoko
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nsoko
# -------------------------------
# Processing City#: 173 | vila franca do campo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vila franca do campo
# -------------------------------
# Processing City#: 174 | ilulissat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ilulissat
# -------------------------------
# Processing City#: 175 | avera
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=avera
# -------------------------------
# Processing City#: 176 | colac
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=colac
# -------------------------------
# Processing City#: 177 | sentyabrskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=sentyabrskiy
# City not found. Skipping...
# -------------------------------
# Processing City#: 178 | qaqortoq
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=qaqortoq
# -------------------------------
# Processing City#: 179 | qui nhon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=qui nhon
# City not found. Skipping...
# -------------------------------
# Processing City#: 180 | scottsbluff
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=scottsbluff
# -------------------------------
# Processing City#: 181 | bethel
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bethel
# -------------------------------
# Processing City#: 182 | kainantu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kainantu
# -------------------------------
# Processing City#: 183 | khash
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=khash
# -------------------------------
# Processing City#: 184 | fairbanks
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=fairbanks
# -------------------------------
# Processing City#: 185 | gamba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=gamba
# -------------------------------
# Processing City#: 186 | pangnirtung
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pangnirtung
# -------------------------------
# Processing City#: 187 | muktagachha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=muktagachha
# City not found. Skipping...
# -------------------------------
# Processing City#: 188 | barentsburg
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=barentsburg
# City not found. Skipping...
# -------------------------------
# Processing City#: 189 | yakeshi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=yakeshi
# -------------------------------
# Processing City#: 190 | port elizabeth
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port elizabeth
# -------------------------------
# Processing City#: 191 | paracatu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=paracatu
# -------------------------------
# Processing City#: 192 | anadyr
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=anadyr
# -------------------------------
# Processing City#: 193 | haibowan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=haibowan
# City not found. Skipping...
# -------------------------------
# Processing City#: 194 | hammerfest
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hammerfest
# -------------------------------
# Processing City#: 195 | umm kaddadah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=umm kaddadah
# -------------------------------
# Processing City#: 196 | hilo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=hilo
# -------------------------------
# Processing City#: 197 | muravlenko
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=muravlenko
# -------------------------------
# Processing City#: 198 | amderma
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=amderma
# City not found. Skipping...
# -------------------------------
# Processing City#: 199 | vrede
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vrede
# -------------------------------
# Processing City#: 200 | kamenskoye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kamenskoye
# City not found. Skipping...
# -------------------------------
# Processing City#: 201 | surab
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=surab
# -------------------------------
# Processing City#: 202 | crixas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=crixas
# -------------------------------
# Processing City#: 203 | tecoanapa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tecoanapa
# -------------------------------
# Processing City#: 204 | gao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=gao
# -------------------------------
# Processing City#: 205 | barabai
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=barabai
# -------------------------------
# Processing City#: 206 | utiroa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=utiroa
# City not found. Skipping...
# -------------------------------
# Processing City#: 207 | praya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=praya
# -------------------------------
# Processing City#: 208 | faanui
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=faanui
# -------------------------------
# Processing City#: 209 | caravelas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=caravelas
# -------------------------------
# Processing City#: 210 | voyinka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=voyinka
# -------------------------------
# Processing City#: 211 | pochutla
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pochutla
# -------------------------------
# Processing City#: 212 | khormuj
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=khormuj
# City not found. Skipping...
# -------------------------------
# Processing City#: 213 | imbituba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=imbituba
# -------------------------------
# Processing City#: 214 | lavrentiya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=lavrentiya
# -------------------------------
# Processing City#: 215 | kahului
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kahului
# -------------------------------
# Processing City#: 216 | samusu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=samusu
# City not found. Skipping...
# -------------------------------
# Processing City#: 217 | upernavik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=upernavik
# -------------------------------
# Processing City#: 218 | kamina
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kamina
# -------------------------------
# Processing City#: 219 | mayumba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mayumba
# -------------------------------
# Processing City#: 220 | garowe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=garowe
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 221 | kargopol
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kargopol
# -------------------------------
# Processing City#: 222 | saleaula
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=saleaula
# City not found. Skipping...
# -------------------------------
# Processing City#: 223 | vila velha
# ...
# -------------------------------
# Processing City#: 544 | mutis
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mutis
# -------------------------------
# Processing City#: 545 | mwinilunga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mwinilunga
# -------------------------------
# Processing City#: 546 | dongsheng
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=dongsheng
# -------------------------------
# Processing City#: 547 | siocon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=siocon
# -------------------------------
# Processing City#: 548 | vryheid
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vryheid
# -------------------------------
# Processing City#: 549 | areka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=areka
# -------------------------------
# Processing City#: 550 | auki
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=auki
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 551 | virginia beach
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=virginia beach
# -------------------------------
# Processing City#: 552 | mount gambier
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mount gambier
# -------------------------------
# Processing City#: 553 | general roca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=general roca
# -------------------------------
# Processing City#: 554 | kloulklubed
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kloulklubed
# -------------------------------
# Processing City#: 555 | manokwari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=manokwari
# -------------------------------
# Processing City#: 556 | ainazi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ainazi
# -------------------------------
# Processing City#: 557 | san pedro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=san pedro
# -------------------------------
# Processing City#: 558 | havre-saint-pierre
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=havre-saint-pierre
# -------------------------------
# Processing City#: 559 | matagami
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=matagami
# -------------------------------
# Processing City#: 560 | olavarria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=olavarria
# -------------------------------
# Processing City#: 561 | payakumbuh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=payakumbuh
# -------------------------------
# Processing City#: 562 | taksimo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=taksimo
# -------------------------------
# Processing City#: 563 | oussouye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=oussouye
# -------------------------------
# Processing City#: 564 | parchim
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=parchim
# -------------------------------
# Processing City#: 565 | taoudenni
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=taoudenni
# -------------------------------
# Processing City#: 566 | kuressaare
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kuressaare
# -------------------------------
# Processing City#: 567 | kota kinabalu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kota kinabalu
# -------------------------------
# Processing City#: 568 | zhezkazgan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=zhezkazgan
# -------------------------------
# Processing City#: 569 | byron bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=byron bay
# -------------------------------
# Processing City#: 570 | guozhen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=guozhen
# -------------------------------
# Processing City#: 571 | namibe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=namibe
# -------------------------------
# Processing City#: 572 | kamaishi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=kamaishi
# -------------------------------
# Processing City#: 573 | turbat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=turbat
# -------------------------------
# Processing City#: 574 | port-gentil
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port-gentil
# -------------------------------
# Processing City#: 575 | ust-kamchatsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ust-kamchatsk
# City not found. Skipping...
# -------------------------------
# Processing City#: 576 | ostersund
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ostersund
# -------------------------------
# Processing City#: 577 | labrea
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=labrea
# City not found. Skipping...
# -------------------------------
# Processing City#: 578 | saldanha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=saldanha
# -------------------------------
# Processing City#: 579 | nyurba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nyurba
# -------------------------------
# Processing City#: 580 | mocuba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mocuba
# -------------------------------
# Processing City#: 581 | porto novo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=porto novo
# -------------------------------
# Processing City#: 582 | matara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=matara
# -------------------------------
# Processing City#: 583 | fereydun kenar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=fereydun kenar
# -------------------------------
# Processing City#: 584 | jacobina
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=jacobina
# -------------------------------
# Processing City#: 585 | chino valley
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=chino valley
# -------------------------------
# Processing City#: 586 | mitsamiouli
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=mitsamiouli
# -------------------------------
# Processing City#: 587 | vilhena
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=vilhena
# -------------------------------
# Processing City#: 588 | codrington
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=codrington
# -------------------------------
# Processing City#: 589 | half moon bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=half moon bay
# -------------------------------
# Processing City#: 590 | shaartuz
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=shaartuz
# City not found. Skipping...
# -------------------------------
# Processing City#: 591 | zhigansk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=zhigansk
# -------------------------------
# Processing City#: 592 | north myrtle beach
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=north myrtle beach
# -------------------------------
# Processing City#: 593 | biltine
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=biltine
# -------------------------------
# Processing City#: 594 | oranjemund
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=oranjemund
# -------------------------------
# Processing City#: 595 | bembereke
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bembereke
# -------------------------------
# Processing City#: 596 | trairi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=trairi
# -------------------------------
# Processing City#: 597 | grenada
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=grenada
# -------------------------------
# Processing City#: 598 | pahrump
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pahrump
# -------------------------------
# Processing City#: 599 | shangrao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=shangrao
# -------------------------------
# Processing City#: 600 | elizabeth city
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=elizabeth city
# -------------------------------
# Processing City#: 601 | fevralsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=fevralsk
# City not found. Skipping...
# -------------------------------
# Processing City#: 602 | coquimbo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=coquimbo
# -------------------------------
# Processing City#: 603 | nioro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=nioro
# -------------------------------
# Processing City#: 604 | somerset east
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=somerset east
# -------------------------------
# Processing City#: 605 | penzance
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=penzance
# ********************
# PAUSE FOR 60 SECONDS
# ********************
# -------------------------------
# Processing City#: 606 | aniva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=aniva
# -------------------------------
# Processing City#: 607 | solhan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=solhan
# -------------------------------
# Processing City#: 608 | alotau
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=alotau
# City not found. Skipping...
# -------------------------------
# Processing City#: 609 | omsukchan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=omsukchan
# -------------------------------
# Processing City#: 610 | alta floresta
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=alta floresta
# -------------------------------
# Processing City#: 611 | pacasmayo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=pacasmayo
# -------------------------------
# Processing City#: 612 | tamandare
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=tamandare
# -------------------------------
# Processing City#: 613 | suntar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=suntar
# -------------------------------
# Processing City#: 614 | port-de-bouc
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=port-de-bouc
# -------------------------------
# Processing City#: 615 | bubaque
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=bubaque
# -------------------------------
# Processing City#: 616 | puerto princesa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=puerto princesa
# -------------------------------
# Processing City#: 617 | solwezi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=solwezi
# -------------------------------
# Processing City#: 618 | ginda
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=ginda
# -------------------------------
# Processing City#: 619 | red bluff
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=7877738b651f6172dfb2597fe3669dab&units=Imperial&q=red bluff
# *************************
# DATA RETRIEVAL COMPLETE
# *************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data.head(15)
# Out:
#              City Country Cloudiness        Date Humidity    Lat     Lng  \
# 0   venado tuerto      ar          0  1536187856       47 -33.75  -61.97
# 1       martapura      id          8  1536187856       99  -3.41  114.85
# 2       jamestown      sh         68  1536187856       74 -33.21   138.6
# 3          barrow      us         20  1536187683       48 -38.31  -60.23
# 4         rikitea      pf         48  1536187857      100 -23.12 -134.97
# 5            tura      ru         92  1536187857       95  25.52   90.21
# 6      butaritari      ki         64  1536187857      100   3.07  172.79
# 7        bengkulu      id
# 8          albany      au         20  1536184440       54  42.65  -73.75
# 9       de-kastri      ru          0  1536187915       89  51.48  140.77
# 10      hithadhoo      mv         92  1536187858      100   -0.6   73.08
# 11       trinidad      co          0  1536187858       62 -33.52   -56.9
# 12     sol-iletsk      ru         36  1536187859       73  51.16      55
# 13         castro      cl         92  1536187859      100 -42.48  -73.76
# 14    broken hill      au         44  1536187859       54 -31.97  141.45
#
#    Max Temp Wind Speed
# 0     67.37      15.82
# 1      77.9       4.18
# 2      51.8      11.34
# 3     68.09      17.49
# 4     72.14      27.78
# 5     77.27       2.95
# 6     84.65      11.79
# 7
# 8     89.96      12.75
# 9     60.71      18.05
# 10    75.11       7.99
# 11    61.34      12.68
# 12    46.94        5.3
# 13    44.42      17.27
# 14    66.74      15.82

# %%
#delete empty rows
city_data = city_data.replace(r'', np.NaN)
city_data = city_data.dropna(how='any')
city_data.count()
# Out:
# City          554
# Country       554
# Cloudiness    554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
#export city data into CSV
city_data.to_csv("city_data.csv", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a plot
city_data.plot.scatter(["Lat"], ["Max Temp"], marker ='o', facecolors ="blue", edgecolors="black", alpha = 1)

#Set the labels
plt.title("City Latitude vs. Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a plot
city_data.plot.scatter(["Lat"], ["Humidity"], marker ='o', facecolors ="blue", edgecolors="black", alpha = 1)

#Set the labels
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a plot
city_data.plot.scatter(["Lat"], ["Cloudiness"], marker ='o', facecolors ="blue", edgecolors="black", alpha = 1)

#Set the labels
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a plot
city_data.plot.scatter(["Lat"], ["Wind Speed"], marker ='o', facecolors ="blue", edgecolors="black", alpha = 1)

#Set the labels
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
